# %%
import pandas as pd

# %%
# Coords 
#这里行号有点错位
a=pd.read_csv('/data3/zrf/BreastTumour/hist2tscript/BC23209_C1_Coords.tsv.gz', sep='\t',compression='gzip')
print(a)
# Out:
#               xcoord  ycoord     lab tumor Unnamed: 4
# 0    C1_18.921_4.999  18.921   4.999    L1        non
# 1    C1_19.973_4.997  19.973   4.997    L2      tumor
# 2    C1_17.887_5.988  17.887   5.988    L3      tumor
# 3     C1_18.931_5.99  18.931   5.990    L4        non
# 4    C1_19.986_6.024  19.986   6.024    L5      tumor
# ..               ...     ...     ...   ...        ...
# 289  C1_8.984_25.971   8.984  25.971  L290      tumor
# 290   C1_7.91_25.988   7.910  25.988  L291      tumor
# 291  C1_6.908_25.994   6.908  25.994  L292      tumor
# 292  C1_7.929_26.972   7.929  26.972  L293      tumor
# 293  C1_6.914_26.992   6.914  26.992  L294      tumor
#
# [294 rows x 5 columns]

# %%
# stdata
a=pd.read_csv('/data3/zrf/BreastTumour/hist2tscript/BC23269_D1_stdata.tsv.gz', sep='\t',compression='gzip',header=0,index_col=0)

print(a)
# Out:
#        ENSG00000000003  ENSG00000000419  ENSG00000000457  ENSG00000000460  \
# 3x34               0.0              0.0              0.0              0.0
# 19x4               0.0              0.0              0.0              0.0
# 3x30               0.0              1.0              0.0              0.0
# 3x31               0.0              0.0              0.0              0.0
# 3x32               0.0              0.0              0.0              0.0
# ...                ...              ...              ...              ...
# 29x7               0.0              0.0              0.0              1.0
# 29x5               0.0              0.0              0.0              0.0
# 19x9               0.0              0.0              0.0              0.0
# 16x24              0.0              0.0              0.0              0.0
# 30x18              0.0              1.0              0.0              0.0
#
#        ENSG00000000938  ENSG00000000971  ENSG00000001036  ENSG00000001084  \
# ...

# %%
# spots

a=pd.read_csv('/data3/zrf/BreastTumour/hist2tscript/spots_BT23901_C2.csv.gz', sep=',',compression='gzip',header=0,index_col=0)
print(a)
# Out:
#               X         Y
# 20x14  5530.793  3753.913
# 22x14  6094.063  3756.240
# 21x14  5795.278  3756.689
# 21x15  5796.873  4040.018
# 22x15  6104.311  4039.241
# ...         ...       ...
# 10x31  2638.573  8713.622
# 11x31  2906.626  8721.273
# 12x31  3210.235  8724.647
# 9x31   2344.257  8720.907
# 10x32  2606.290  9014.296
#
# [292 rows x 2 columns]

# %%
metadataPath = "/data3/zrf/BreastTumour/hist2tscript/metadata.csv"
metadata=pd.read_csv(metadataPath,sep=',',header=0)
print(metadata)
# Out:
#             type  patient replicate              count_matrix  \
# 0   HER2_luminal  BC23287        C1  BC23287_C1_stdata.tsv.gz
# 1   HER2_luminal  BC23287        C2  BC23287_C2_stdata.tsv.gz
# 2   HER2_luminal  BC23287        D1  BC23287_D1_stdata.tsv.gz
# 3   HER2_luminal  BC23450        D2  BC23450_D2_stdata.tsv.gz
# 4   HER2_luminal  BC23450        E1  BC23450_E1_stdata.tsv.gz
# ..           ...      ...       ...                       ...
# 63          TNBC  BC23377        C2  BC23377_C2_stdata.tsv.gz
# 64          TNBC  BC23377        D1  BC23377_D1_stdata.tsv.gz
# 65          TNBC  BC23803        D2  BC23803_D2_stdata.tsv.gz
# 66          TNBC  BC23803        E1  BC23803_E1_stdata.tsv.gz
# 67          TNBC  BC23803        E2  BC23803_E2_stdata.tsv.gz
#
#       histology_image         spot_coordinates          tumor_annotation
# 0   HE_BT23287_C1.jpg  spots_BT23287_C1.csv.gz  BC23287_C1_Coords.tsv.gz
# 1   HE_BT23287_C2.jpg  spots_BT23287_C2.csv.gz  BC23287_C2_Coords.tsv.gz
# ...
